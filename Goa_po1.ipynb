# %%
import pandas as pd

# %%
df= pd.read_csv("/content/data (1).csv", encoding='latin1')
df
# Out:
#        stn_code       sampling_date           state   location agency  \
# 0         150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1         151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2         152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3         150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4         151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# ...         ...                 ...             ...        ...    ...
# 28065       NaN          10/10/2006           Assam   Guwahati    NaN
# 28066       NaN          10/11/2006           Assam   Guwahati    NaN
# 28067       NaN          10/12/2006           Assam   Guwahati    NaN
# 28068       NaN          13/10/2006           Assam   Guwahati    NaN
# 28069       NaN          14/10/2006           Assam   Guwahati    NaN
#
#                                      type   so2   no2   rspm    spm  \
# ...

# %%
data=df.loc[df['state'] =='Assam']

data
# Out:
#        stn_code       sampling_date  state  location agency  \
# 26458     193.0   January - M011991  Assam  Guwahati   ASPB
# 26459     194.0   January - M011991  Assam  Guwahati   ASPB
# 26460     195.0   January - M011991  Assam  Guwahati   ASPB
# 26461     193.0  February - M021991  Assam  Guwahati   ASPB
# 26462     194.0  February - M021991  Assam  Guwahati   ASPB
# ...         ...                 ...    ...       ...    ...
# 28065       NaN          10/10/2006  Assam  Guwahati    NaN
# 28066       NaN          10/11/2006  Assam  Guwahati    NaN
# 28067       NaN          10/12/2006  Assam  Guwahati    NaN
# 28068       NaN          13/10/2006  Assam  Guwahati    NaN
# 28069       NaN          14/10/2006  Assam  Guwahati    NaN
#
#                          type   so2   no2   rspm    spm  \
# 26458                     NaN  14.0  22.6    NaN   43.0
# 26459                     NaN   8.0  17.3    NaN   69.0
# 26460                     NaN  13.6   7.5    NaN   28.0
# ...

# %%
import pandas as pd
import seaborn as sns
data=df.loc[df['state'] =='Assam']
sns.relplot(data=data,x='location',y='so2',hue='location')
